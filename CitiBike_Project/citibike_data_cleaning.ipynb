# %%
import pandas as pd

# %%
JC_Dec_20 = pd.read_csv('Resources/JC-202012-citibike-tripdata.csv')
JC_Jan_21 = pd.read_csv('Resources/JC-202101-citibike-tripdata.csv')
JC_Feb_21 = pd.read_csv('Resources/JC-202102-citibike-tripdata.csv')
JC_Mar_21 = pd.read_csv('Resources/JC-202103-citibike-tripdata.csv')
JC_Apr_21 = pd.read_csv('Resources/JC-202104-citibike-tripdata.csv')
JC_May_21 = pd.read_csv('Resources/JC-202105-citibike-tripdata.csv')
JC_Jun_21 = pd.read_csv('Resources/JC-202106-citibike-tripdata.csv')
JC_Jul_21 = pd.read_csv('Resources/JC-202107-citibike-tripdata.csv')
JC_Aug_21 = pd.read_csv('Resources/JC-202108-citibike-tripdata.csv')
JC_Sep_21 = pd.read_csv('Resources/JC-202109-citibike-tripdata.csv')

# %%
frames = [JC_Feb_21, JC_Mar_21, JC_Apr_21, JC_May_21, JC_Jun_21, JC_Jul_21, JC_Aug_21, JC_Sep_21]

#concatenate dataframes
jc_feb_thru_sep = pd.concat(frames, sort=False)

# %%
print(jc_feb_thru_sep['rideable_type'].value_counts())
# Out:
# classic_bike              296674
# docked_bike               139213
# motivate_dockless_bike         1
# Name: rideable_type, dtype: int64

# %%
jc_feb_thru_sep.to_csv(r'C:\Users\Jtc\Desktop\CitiBike\jc_feb_through_sep_21.csv', index = True)

# %%
NYC_Jan_21 = pd.read_csv('Resources/202101-citibike-tripdata.csv')
NYC_Feb_21 = pd.read_csv('Resources/202102-citibike-tripdata.csv')
NYC_Mar_21 = pd.read_csv('Resources/202103-citibike-tripdata.csv')
NYC_Apr_21 = pd.read_csv('Resources/202104-citibike-tripdata.csv')
NYC_May_21 = pd.read_csv('Resources/202105-citibike-tripdata.csv')
NYC_Jun_21 = pd.read_csv('Resources/202106-citibike-tripdata.csv')
NYC_Jul_21 = pd.read_csv('Resources/202107-citibike-tripdata.csv')
NYC_Aug_21 = pd.read_csv('Resources/202108-citibike-tripdata.csv')
NYC_Sep_21 = pd.read_csv('Resources/202109-citibike-tripdata.csv')
# Out:
# c:\users\jtc\anaconda3\envs\datacoursepython\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (5,7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
# c:\users\jtc\anaconda3\envs\datacoursepython\lib\site-packages\IPython\core\interactiveshell.py:3169: DtypeWarning: Columns (7) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
print(NYC_Feb_21.dtypes)
# Out:
# ride_id                object
# rideable_type          object
# started_at             object
# ended_at               object
# start_station_name     object
# start_station_id       object
# end_station_name       object
# end_station_id         object
# start_lat             float64
# start_lng             float64
# end_lat               float64
# end_lng               float64
# member_casual          object
# dtype: object

# %%
NYC_Mar_21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  4D69477D59E576ED   docked_bike  2021-03-22 18:30:56  2021-03-22 18:37:15
# 1  7F563DA4AC198E0A   docked_bike  2021-03-30 11:47:49  2021-03-30 12:00:40
# 2  C5E0F4FEDA9C2F86   docked_bike  2021-03-04 19:53:50  2021-03-04 20:11:53
# 3  61B726C1884DB04C   docked_bike  2021-03-20 13:05:54  2021-03-20 13:11:16
# 4  7807BB9281BCFD8D   docked_bike  2021-03-20 08:31:09  2021-03-20 08:35:41
#
#                     start_station_name start_station_id  \
# 0         Willoughby Ave & Wyckoff Ave          5010.02
# 1            Franklin Ave & Myrtle Ave          4715.01
# 2  Adam Clayton Powell Blvd & W 141 St          7893.05
# 3                Bayard St & Baxter St          5351.03
# 4                Bayard St & Baxter St          5351.03
#
#           end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 0    Cedar St & Myrtle Ave        4751.01  40.705614 -73.921530  40.697842
# ...

# %%
mar_docked = NYC_Mar_21.loc[NYC_Mar_21["rideable_type"] == "docked_bike"]

# %%
mar_docked.nunique()
# Out:
# ride_id               1531094
# rideable_type               1
# started_at             992529
# ended_at               996932
# start_station_name       1337
# start_station_id         2649
# end_station_name         1352
# end_station_id           2241
# start_lat                1659
# start_lng                1653
# end_lat                  1997
# end_lng                  1986
# member_casual               2
# dtype: int64

# %%
NYC_Apr_21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  7099F9531C9DA16D   docked_bike  2021-04-28 17:27:24  2021-04-28 17:34:31
# 1  EDC6F1B1A69A7863   docked_bike  2021-04-27 17:28:02  2021-04-27 17:33:07
# 2  431A76830E10408A   docked_bike  2021-04-28 18:05:19  2021-04-28 18:10:48
# 3  C00248A0ADC009FA   docked_bike  2021-04-20 21:35:47  2021-04-20 21:56:31
# 4  BE78810D746EE516   docked_bike  2021-04-30 00:34:54  2021-04-30 01:03:29
#
#         start_station_name start_station_id          end_station_name  \
# 0  DeKalb Ave & Hudson Ave          4513.06       Douglass St & 4 Ave
# 1       E 47 St & Park Ave          6584.12           W 52 St & 6 Ave
# 2       E 47 St & Park Ave          6584.12           W 52 St & 6 Ave
# 3  Irving Ave & DeKalb Ave          4898.02  Division Ave & Hooper St
# 4         3 Ave & E 112 St          7543.15  E 115 St & Lexington Ave
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
NYC_Mar_21.value_counts()

# %%
NYC_Mar_21.nunique()
# Out:
# ride_id               1531094
# rideable_type               1
# started_at             992529
# ended_at               996932
# start_station_name       1337
# start_station_id         2649
# end_station_name         1352
# end_station_id           2241
# start_lat                1659
# start_lng                1653
# end_lat                  1997
# end_lng                  1986
# member_casual               2
# dtype: int64

# %%
NYC_Apr_21.nunique()
# Out:
# ride_id               2067669
# rideable_type               2
# started_at            1179762
# ended_at              1182524
# start_station_name       1395
# start_station_id         2742
# end_station_name         1417
# end_station_id           2351
# start_lat                1732
# start_lng                1730
# end_lat                  2082
# end_lng                  2071
# member_casual               2
# dtype: int64

# %%
NYC_May_21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  E12103A91226099A   docked_bike  2021-05-06 17:25:01  2021-05-06 17:45:25
# 1  26A3DC47FE0EA3A3   docked_bike  2021-05-13 12:48:08  2021-05-13 13:07:37
# 2  A99F2E1D627B088F   docked_bike  2021-05-16 08:30:13  2021-05-16 08:45:47
# 3  43E79A45997B7390   docked_bike  2021-05-01 08:38:14  2021-05-01 08:54:27
# 4  8B3CC649F4F58816   docked_bike  2021-05-09 08:12:31  2021-05-09 08:27:05
#
#    start_station_name start_station_id        end_station_name end_station_id  \
# 0  Broadway & W 60 St          6948.11         1 Ave & E 78 St        7020.09
# 1  Broadway & W 25 St          6173.08       E 2 St & Avenue B        5515.02
# 2       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
# 3       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
# 4       46 Ave & 5 St          6286.02  34th Ave & Vernon Blvd        6873.01
#
# ...

# %%
NYC_Jun_21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  6339C86D47EC0FAB   docked_bike  2021-06-02 17:18:45  2021-06-02 17:26:17
# 1  CDE3C147775B4002   docked_bike  2021-06-04 21:01:46  2021-06-04 21:32:09
# 2  D335C3F6B412B846   docked_bike  2021-06-15 16:39:36  2021-06-15 16:55:02
# 3  8DA6810777C89735   docked_bike  2021-06-08 11:36:40  2021-06-08 11:39:41
# 4  62D9B66A3A1D9FDF   docked_bike  2021-06-18 12:48:43  2021-06-18 13:04:14
#
#       start_station_name  start_station_id       end_station_name  \
# 0        W 51 St & 6 Ave           6740.10  E 66 St & Madison Ave
# 1       W 56 St & 10 Ave           6955.01      E 9 St & Avenue C
# 2  E 56 St & Madison Ave           6732.01        E 16 St & 5 Ave
# 3        E 68 St & 3 Ave           6896.16        1 Ave & E 62 St
# 4        E 48 St & 5 Ave           6626.01        W 20 St & 8 Ave
#
#   end_station_id  start_lat  start_lng    end_lat    end_lng member_casual
# ...

# %%
NYC_Jul_21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  247BA541A9674BF3  classic_bike  2021-07-09 16:05:36  2021-07-09 16:18:09
# 1  125C9ACA270A5E2D  classic_bike  2021-07-11 16:23:35  2021-07-11 16:29:07
# 2  2E26264BCC15BA05  classic_bike  2021-07-23 06:22:40  2021-07-23 06:36:13
# 3  A56D23A088563424  classic_bike  2021-07-05 16:08:10  2021-07-05 16:36:00
# 4  1451F4BB884C5335  classic_bike  2021-07-26 12:28:57  2021-07-26 12:30:21
#
#      start_station_name  start_station_id                    end_station_name  \
# 0       5 Ave & E 93 St           7372.10  Frederick Douglass Blvd & W 117 St
# 1       5 Ave & E 93 St           7372.10                  E 88 St & Park Ave
# 2        34 St & 38 Ave           6453.02          McGuinness Blvd & Eagle St
# 3  Lenox Ave & W 111 St           7602.05                     5 Ave & E 78 St
# 4     6 Ave & Broome St           5610.09                    6 Ave & Canal St
#
# ...

# %%
NYC_Aug_21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  FB6B89D05B67EBED  classic_bike  2021-08-24 15:59:57  2021-08-24 16:42:07
# 1  E13DA3E30CEF8DFC  classic_bike  2021-08-18 13:12:01  2021-08-18 13:21:26
# 2  56617490AB8AE69C  classic_bike  2021-08-17 14:31:23  2021-08-17 14:35:34
# 3  CA908B271C7D6663  classic_bike  2021-08-11 10:00:12  2021-08-11 10:31:01
# 4  3E170CE1F4FE179D  classic_bike  2021-08-12 19:28:38  2021-08-12 19:48:50
#
#       start_station_name  start_station_id  \
# 0     Broadway & E 21 St           6098.10
# 1        E 13 St & 2 Ave           5820.08
# 2        E 95 St & 3 Ave           7365.13
# 3  Madison Ave & E 82 St           7188.13
# 4        E 74 St & 1 Ave           6953.08
#
#                                 end_station_name end_station_id  start_lat  \
# 0  Central Park North & Adam Clayton Powell Blvd        7617.07  40.739888
# 1                            Henry St & Grand St        5294.04  40.731539
# ...

# %%
NYC_Sep_21.head()
# Out:
#             ride_id rideable_type           started_at             ended_at  \
# 0  22C33F42C6A0E28E  classic_bike  2021-09-01 10:26:45  2021-09-01 10:43:23
# 1  035F743147FCFCDE  classic_bike  2021-09-04 09:52:40  2021-09-04 10:09:19
# 2  9C43CF6A07DACBC6  classic_bike  2021-09-06 17:07:40  2021-09-06 17:34:44
# 3  253A1A5B20CC78EE  classic_bike  2021-09-28 16:53:43  2021-09-28 17:03:00
# 4  5E8F164D6798CEFA  classic_bike  2021-09-19 09:37:47  2021-09-19 09:53:42
#
#                 start_station_name  start_station_id         end_station_name  \
# 0      Central Park West & W 72 St           7141.07          E 51 St & 1 Ave
# 1             William St & Pine St           5065.12                      NaN
# 2             Fulton St & Broadway           5175.08         Jay St & Tech Pl
# 3  West Drive & Prospect Park West           3651.04  Ocean Pkwy & Church Ave
# 4            Lorimer St & Broadway           4965.01         Jay St & Tech Pl
#
# ...

# %%
frames = [NYC_Feb_21, NYC_Mar_21, NYC_Apr_21, NYC_May_21, NYC_Jun_21, NYC_Jul_21, NYC_Aug_21,NYC_Sep_21]

#concatenate dataframes
nyc_feb_thru_sep = pd.concat(frames, sort=False)

# %%
nyc_feb_thru_sep.dropna()
# Out:
#                   ride_id rideable_type           started_at  \
# 0        BBA33D73DECE976F   docked_bike  2021-02-26 16:38:54
# 1        B63D7AFF9AC5B6D4   docked_bike  2021-02-17 11:09:11
# 2        52B829195C469D99   docked_bike  2021-02-26 18:33:29
# 3        19C84ECA2B468476   docked_bike  2021-02-26 12:48:35
# 4        C0DDB771E70D9DF5   docked_bike  2021-02-25 17:23:22
# ...                   ...           ...                  ...
# 3280216  8A1C8DB4249BF100  classic_bike  2021-09-26 16:00:45
# 3280217  C290EE73DF58AD79  classic_bike  2021-09-07 08:22:06
# 3280218  E42F8B93C4168658  classic_bike  2021-09-30 20:50:23
# 3280219  7221F0C58026A827  classic_bike  2021-09-08 19:06:24
# 3280220  689F3FAE372C013C  classic_bike  2021-09-27 07:58:57
#
#                     ended_at          start_station_name start_station_id  \
# 0        2021-02-26 16:44:37          E 84 St & Park Ave          7243.04
# 1        2021-02-17 11:26:47     Macon St & Nostrand Ave          4214.03
# ...

# %%
nyc_feb_thru_sep.to_csv(r'C:\Users\Jtc\Desktop\CitiBike\feb_through_sep_21.csv', index = True)

# %%
nyc_feb_thru_sep['start_station_id'].value_counts()
# Out:
# 5980.07    87843
# 6140.05    85507
# 5329.03    81183
# 6822.09    77086
# 6173.08    74218
#            ...
# 8715.06        1
# 8478.11        1
# SYS033         1
# 8435.06        1
# 8543.01        1
# Name: start_station_id, Length: 2941, dtype: int64

# %%
nyc_feb_thru_sep['start_station_name'].value_counts()
# Out:
# E 17 St & Broadway              88726
# W 21 St & 6 Ave                 88279
# West St & Chambers St           82113
# 1 Ave & E 68 St                 79372
# Broadway & W 25 St              75728
#                                 ...
# Bleecker St & Lafayette St          9
# Anthony Ave & E Burnside Ave        2
# Pier 40 Dock Station                2
# MTL-ECO51-1                         2
# Pier 40 X2                          1
# Name: start_station_name, Length: 1534, dtype: int64

# %%
station = nyc_feb_thru_sep.loc[nyc_feb_thru_sep['start_station_id'] == "5980.07"]

# %%
station.head()
# Out:
#                  ride_id rideable_type           started_at  \
# 528543  9F170BBB31314152   docked_bike  2021-02-17 18:52:08
# 528562  B8EEBEAD9E42B7F8   docked_bike  2021-02-17 15:23:50
# 528564  6F4AB8A6FF98F2AC   docked_bike  2021-02-13 19:27:28
# 528565  330E70DBAF30DB50   docked_bike  2021-02-17 05:42:18
# 528567  ED3C4ADBDB2F3FA9   docked_bike  2021-02-26 14:11:29
#
#                    ended_at  start_station_name start_station_id  \
# 528543  2021-02-17 19:00:43  E 17 St & Broadway          5980.07
# 528562  2021-02-17 15:32:37  E 17 St & Broadway          5980.07
# 528564  2021-02-13 19:34:51  E 17 St & Broadway          5980.07
# 528565  2021-02-17 05:47:57  E 17 St & Broadway          5980.07
# 528567  2021-02-26 14:18:23  E 17 St & Broadway          5980.07
#
#        end_station_name end_station_id  start_lat  start_lng    end_lat  \
# 528543  E 33 St & 5 Ave        6322.01  40.737050 -73.990093  40.747659
# ...

# %%
nyc_feb_thru_sep.loc[(nyc_feb_thru_sep['start_station_id'] != "5980.07")&(nyc_feb_thru_sep['start_station_name'] == "E 17 St & Broadway")].info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 87843 entries, 528543 to 3266720
# Data columns (total 13 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ride_id             87843 non-null  object
#  1   rideable_type       87843 non-null  object
#  2   started_at          87843 non-null  object
#  3   ended_at            87843 non-null  object
#  4   start_station_name  87843 non-null  object
#  5   start_station_id    87843 non-null  object
#  6   end_station_name    87583 non-null  object
#  7   end_station_id      87583 non-null  object
#  8   start_lat           87843 non-null  float64
#  9   start_lng           87843 non-null  float64
#  10  end_lat             87671 non-null  float64
#  11  end_lng             87671 non-null  float64
#  12  member_casual       87843 non-null  object
# dtypes: float64(4), object(9)
# memory usage: 9.4+ MB

# %%
nyc_feb_thru_sep['start_lat'].value_counts()
# Out:
# 40.711444    72332
# 40.718822    63974
# 40.751873    62082
# 40.734814    61794
# 40.752694    56598
#              ...
# 40.842102        1
# 40.868487        1
# 40.728487        1
# 40.860424        1
# 40.781152        1
# Name: start_lat, Length: 2593, dtype: int64

# %%
nyc_feb_thru_sep.nunique()
# Out:
# ride_id               19587664
# rideable_type                3
# started_at            10308610
# ended_at              10330077
# start_station_name        1534
# start_station_id          2941
# end_station_name          1597
# end_station_id            3105
# start_lat                 2593
# start_lng                 2586
# end_lat                   2346
# end_lng                   2330
# member_casual                2
# dtype: int64

# %%
docked = nyc_feb_thru_sep.loc[nyc_feb_thru_sep["rideable_type"] == "docked_bike"]

# %%
docked.nunique(30)
# Out:
#                 ride_id rideable_type           started_at  \
# 3960   191D944F8EF52153   docked_bike  2021-02-27 11:39:56
# 4019   1758C2E5CE226065   docked_bike  2021-02-05 15:25:41
# 4020   1F49563E6E688E5E   docked_bike  2021-02-08 20:03:42
# 4473   29E77E023B99D3DA   docked_bike  2021-02-26 20:41:18
# 4479   FE2930A03812D6FD   docked_bike  2021-02-12 13:33:25
# 6739   6D596719E9ED7180   docked_bike  2021-02-26 10:19:49
# 6740   DC50C95B5D7E7142   docked_bike  2021-02-10 10:04:02
# 6741   043C14F4A4E9C8D6   docked_bike  2021-02-26 08:39:10
# 7668   416DA9BAF7A56298   docked_bike  2021-02-17 08:08:37
# 13134  6D3D0C56D9B10EDE   docked_bike  2021-02-14 06:56:55
# 13135  B2C6E2C8982DAD84   docked_bike  2021-02-24 06:20:59
# 13136  6769E636B21AB8B0   docked_bike  2021-02-12 06:51:49
# 13137  A63089D53469A00D   docked_bike  2021-02-24 13:56:25
# 13139  CEB8A53FD1D102A3   docked_bike  2021-02-06 18:41:43
# 13142  1B3D777829E13FB5   docked_bike  2021-02-25 05:41:04
# ...
